# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# #### 1.Import and merge data

# %%
features = pd.read_csv("data/features.csv")
features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
stores = pd.read_csv("data/stores.csv")
stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
train = pd.read_csv("data/train.csv")
train.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
features_join_stores = pd.merge(features,stores, on='Store') # Merge features and stores together
features_join_stores.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday Type  \
# 0        NaN        NaN        NaN  211.096358         8.106      False    A
# 1        NaN        NaN        NaN  211.242170         8.106       True    A
# 2        NaN        NaN        NaN  211.289143         8.106      False    A
# 3        NaN        NaN        NaN  211.319643         8.106      False    A
# 4        NaN        NaN        NaN  211.350143         8.106      False    A
#
#      Size
# 0  151315
# 1  151315
# 2  151315
# 3  151315
# 4  151315

# %%
data = pd.merge(train,features_join_stores,on=['Store', 'Date', 'IsHoliday']) # Merge previous df with train
data
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  2010-02-05      24924.50      False        42.31
# 1           1     2  2010-02-05      50605.27      False        42.31
# 2           1     3  2010-02-05      13740.12      False        42.31
# 3           1     4  2010-02-05      39954.04      False        42.31
# 4           1     5  2010-02-05      32229.38      False        42.31
# ...       ...   ...         ...           ...        ...          ...
# 421565     45    93  2012-10-26       2487.80      False        58.85
# 421566     45    94  2012-10-26       5203.31      False        58.85
# 421567     45    95  2012-10-26      56017.47      False        58.85
# 421568     45    97  2012-10-26       6817.48      False        58.85
# 421569     45    98  2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0            2.572        NaN        NaN        NaN        NaN        NaN
# 1            2.572        NaN        NaN        NaN        NaN        NaN
# 2            2.572        NaN        NaN        NaN        NaN        NaN
# 3            2.572        NaN        NaN        NaN        NaN        NaN
# 4            2.572        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 421565       3.882    4018.91      58.08      100.0     211.94     858.33
# 421566       3.882    4018.91      58.08      100.0     211.94     858.33
# 421567       3.882    4018.91      58.08      100.0     211.94     858.33
# 421568       3.882    4018.91      58.08      100.0     211.94     858.33
# 421569       3.882    4018.91      58.08      100.0     211.94     858.33
#
#                CPI  Unemployment Type    Size
# 0       211.096358         8.106    A  151315
# 1       211.096358         8.106    A  151315
# 2       211.096358         8.106    A  151315
# 3       211.096358         8.106    A  151315
# 4       211.096358         8.106    A  151315
# ...            ...           ...  ...     ...
# 421565  192.308899         8.667    B  118221
# 421566  192.308899         8.667    B  118221
# 421567  192.308899         8.667    B  118221
# 421568  192.308899         8.667    B  118221
# 421569  192.308899         8.667    B  118221
#
# [421570 rows x 16 columns]

# %% [markdown]
# #### 2. Check descriptive statistics

# %%
data.describe() # Check descriptive statistics
# Out:
#                Store           Dept   Weekly_Sales    Temperature  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123      60.090059
# std        12.785297      30.492054   22711.183519      18.447931
# min         1.000000       1.000000   -4988.940000      -2.060000
# 25%        11.000000      18.000000    2079.650000      46.680000
# 50%        22.000000      37.000000    7612.030000      62.090000
# 75%        33.000000      74.000000   20205.852500      74.280000
# max        45.000000      99.000000  693099.360000     100.140000
#
#           Fuel_Price      MarkDown1      MarkDown2      MarkDown3  \
# count  421570.000000  150681.000000  111248.000000  137091.000000
# mean        3.361027    7246.420196    3334.628621    1439.421384
# std         0.458515    8291.221345    9475.357325    9623.078290
# min         2.472000       0.270000    -265.760000     -29.100000
# 25%         2.933000    2240.270000      41.600000       5.080000
# 50%         3.452000    5347.450000     192.000000      24.600000
# 75%         3.738000    9210.900000    1926.940000     103.990000
# max         4.468000   88646.760000  104519.540000  141630.610000
#
#            MarkDown4      MarkDown5            CPI   Unemployment  \
# count  134967.000000  151432.000000  421570.000000  421570.000000
# mean     3383.168256    4628.975079     171.201947       7.960289
# std      6292.384031    5962.887455      39.159276       1.863296
# min         0.220000     135.160000     126.064000       3.879000
# 25%       504.220000    1878.440000     132.022667       6.891000
# 50%      1481.310000    3359.450000     182.318780       7.866000
# 75%      3595.040000    5563.800000     212.416993       8.572000
# max     67474.850000  108519.280000     227.232807      14.313000
#
#                 Size
# count  421570.000000
# mean   136727.915739
# std     60980.583328
# min     34875.000000
# 25%     93638.000000
# 50%    140167.000000
# 75%    202505.000000
# max    219622.000000

# %% [markdown]
# #### 3. Check missing value

# %%
data.isna().sum()*100/len(data) # Check percentage of missing values
# Out:
# Store            0.000000
# Dept             0.000000
# Date             0.000000
# Weekly_Sales     0.000000
# IsHoliday        0.000000
# Temperature      0.000000
# Fuel_Price       0.000000
# MarkDown1       64.257181
# MarkDown2       73.611025
# MarkDown3       67.480845
# MarkDown4       67.984676
# MarkDown5       64.079038
# CPI              0.000000
# Unemployment     0.000000
# Type             0.000000
# Size             0.000000
# dtype: float64

# %% [markdown]
# The `MarkDown1-5` columns have missing value more than 50%. We will drop these columns.

# %%
data.drop(["MarkDown1","MarkDown2","MarkDown3","MarkDown4","MarkDown5"],axis=1,inplace=True) # Drop missing columns

# %%
data.isna().sum()*100/len(data) # Check percentage of missing values
# Out:
# Store           0.0
# Dept            0.0
# Date            0.0
# Weekly_Sales    0.0
# IsHoliday       0.0
# Temperature     0.0
# Fuel_Price      0.0
# CPI             0.0
# Unemployment    0.0
# Type            0.0
# Size            0.0
# dtype: float64

# %% [markdown]
# #### 4. Check Correlation

# %%
corr = data.corr() # Correlation Matrix
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_bcb4b_row0_col0,#T_bcb4b_row1_col1,#T_bcb4b_row2_col2,#T_bcb4b_row3_col3,#T_bcb4b_row4_col4,#T_bcb4b_row5_col5,#T_bcb4b_row6_col6,#T_bcb4b_row7_col7,#T_bcb4b_row8_col8{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_bcb4b_row0_col1{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_bcb4b_row0_col2,#T_bcb4b_row0_col8,#T_bcb4b_row3_col4,#T_bcb4b_row4_col3,#T_bcb4b_row6_col0,#T_bcb4b_row6_col1,#T_bcb4b_row6_col5,#T_bcb4b_row6_col7,#T_bcb4b_row7_col6{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_bcb4b_row0_col3,#T_bcb4b_row1_col3,#T_bcb4b_row2_col4,#T_bcb4b_row4_col0,#T_bcb4b_row6_col3,#T_bcb4b_row8_col3{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_bcb4b_row0_col4,#T_bcb4b_row3_col2{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_bcb4b_row0_col5{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_bcb4b_row0_col6,#T_bcb4b_row5_col3{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_bcb4b_row0_col7{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_bcb4b_row1_col0{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_bcb4b_row1_col2,#T_bcb4b_row7_col4{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_bcb4b_row1_col4{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_bcb4b_row1_col5,#T_bcb4b_row2_col5,#T_bcb4b_row7_col3,#T_bcb4b_row8_col5{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_bcb4b_row1_col6{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_bcb4b_row1_col7{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T_bcb4b_row1_col8,#T_bcb4b_row6_col8{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_bcb4b_row2_col0,#T_bcb4b_row4_col8,#T_bcb4b_row5_col6{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_bcb4b_row2_col1,#T_bcb4b_row3_col8{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_bcb4b_row2_col3{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_bcb4b_row2_col6{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_bcb4b_row2_col7{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_bcb4b_row2_col8{
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }#T_bcb4b_row3_col0{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_bcb4b_row3_col1,#T_bcb4b_row5_col1{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_bcb4b_row3_col5{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_bcb4b_row3_col6,#T_bcb4b_row5_col0,#T_bcb4b_row8_col6{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_bcb4b_row3_col7{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_bcb4b_row4_col1,#T_bcb4b_row7_col1{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_bcb4b_row4_col2{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_bcb4b_row4_col5{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_bcb4b_row4_col6{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_bcb4b_row4_col7{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_bcb4b_row5_col2{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_bcb4b_row5_col4{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_bcb4b_row5_col7{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_bcb4b_row5_col8{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_bcb4b_row6_col2{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_bcb4b_row6_col4{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_bcb4b_row7_col0{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_bcb4b_row7_col2{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_bcb4b_row7_col5{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_bcb4b_row7_col8{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_bcb4b_row8_col0{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_bcb4b_row8_col1{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_bcb4b_row8_col2{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_bcb4b_row8_col4{
#             background-color:  #5470de;
#             color:  #000000;
#         }#T_bcb4b_row8_col7{
#             background-color:  #7396f5;
#             color:  #000000;
#         }</style><table id="T_bcb4b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Store</th>        <th class="col_heading level0 col1" >Dept</th>        <th class="col_heading level0 col2" >Weekly_Sales</th>        <th class="col_heading level0 col3" >IsHoliday</th>        <th class="col_heading level0 col4" >Temperature</th>        <th class="col_heading level0 col5" >Fuel_Price</th>        <th class="col_heading level0 col6" >CPI</th>        <th class="col_heading level0 col7" >Unemployment</th>        <th class="col_heading level0 col8" >Size</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bcb4b_level0_row0" class="row_heading level0 row0" >Store</th>
#                         <td id="T_bcb4b_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_bcb4b_row0_col1" class="data row0 col1" >0.024004</td>
#                         <td id="T_bcb4b_row0_col2" class="data row0 col2" >-0.085195</td>
#                         <td id="T_bcb4b_row0_col3" class="data row0 col3" >-0.000548</td>
#                         <td id="T_bcb4b_row0_col4" class="data row0 col4" >-0.050097</td>
#                         <td id="T_bcb4b_row0_col5" class="data row0 col5" >0.065290</td>
#                         <td id="T_bcb4b_row0_col6" class="data row0 col6" >-0.211088</td>
#                         <td id="T_bcb4b_row0_col7" class="data row0 col7" >0.208552</td>
#                         <td id="T_bcb4b_row0_col8" class="data row0 col8" >-0.182881</td>
#             </tr>
#             <tr>
#                         <th id="T_bcb4b_level0_row1" class="row_heading level0 row1" >Dept</th>
#                         <td id="T_bcb4b_row1_col0" class="data row1 col0" >0.024004</td>
#                         <td id="T_bcb4b_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_bcb4b_row1_col2" class="data row1 col2" >0.148032</td>
#                         <td id="T_bcb4b_row1_col3" class="data row1 col3" >0.000916</td>
#                         <td id="T_bcb4b_row1_col4" class="data row1 col4" >0.004437</td>
#                         <td id="T_bcb4b_row1_col5" class="data row1 col5" >0.003572</td>
#                         <td id="T_bcb4b_row1_col6" class="data row1 col6" >-0.007477</td>
#                         <td id="T_bcb4b_row1_col7" class="data row1 col7" >0.007837</td>
#                         <td id="T_bcb4b_row1_col8" class="data row1 col8" >-0.002966</td>
#             </tr>
#             <tr>
#                         <th id="T_bcb4b_level0_row2" class="row_heading level0 row2" >Weekly_Sales</th>
#                         <td id="T_bcb4b_row2_col0" class="data row2 col0" >-0.085195</td>
#                         <td id="T_bcb4b_row2_col1" class="data row2 col1" >0.148032</

# %% [markdown]
# Focus on Weekly_Sales column and other columns row, you will see the correlation between them.
#
# The `Positive Correlation`s are Size, Dept, IsHoliday. If these columns increase, the Weekly_Sales increase.
#
# The `Negative Correlation`s are Store, CPI, Unemployment. If these columns increase, the Weekly_Sales decrease.
#
# The `No Correlation`s are Temperature, Fuel_Price. We drop this out becaause it's no meaning to predict Weekly_Sales.

# %%
data.drop(["Temperature","Fuel_Price"],axis=1,inplace=True)

# %% [markdown]
# #### 5. Feature Extractions

# %%
data["DateTime"] = pd.to_datetime(data["Date"]) # Cast Date column to DateTime
data["Week"] = data["DateTime"].dt.week # Extract week from date
data["Month"] = data["DateTime"].dt.month # Extract month from date
data["Year"] = data["DateTime"].dt.year # Extract year from date

# %%
holiday_dict = {"SuperBowl":['2010-02-12', '2011-02-11', '2012-02-10', '2013-02-08'],
                "LaborDay":['2010-09-10','2011-09-09', '2012-09-07', '2013-09-06'],
                "ThanksGiving":['2010-11-26', '2011-11-25', '2012-11-23', '2013-11-29'],
                "Christmas":['2010-12-31', '2011-12-30', '2012-12-28', '2013-12-27']}

# %%
special_day = []
for date in data["Date"].values:
    if date in holiday_dict["SuperBowl"]:
        special_day.append(0)
    elif date in holiday_dict["LaborDay"]:
        special_day.append(1)
    elif date in holiday_dict["ThanksGiving"]:
        special_day.append(2)
    elif date in holiday_dict["Christmas"]:
        special_day.append(3)
    else:
        special_day.append(-1)
data["SpecialDay"] = special_day
data.drop(["Date"],axis=1,inplace=True)

# %%
data
# Out:
#         Store  Dept  Weekly_Sales  IsHoliday         CPI  Unemployment Type  \
# 0           1     1      24924.50      False  211.096358         8.106    A
# 1           1     2      50605.27      False  211.096358         8.106    A
# 2           1     3      13740.12      False  211.096358         8.106    A
# 3           1     4      39954.04      False  211.096358         8.106    A
# 4           1     5      32229.38      False  211.096358         8.106    A
# ...       ...   ...           ...        ...         ...           ...  ...
# 421565     45    93       2487.80      False  192.308899         8.667    B
# 421566     45    94       5203.31      False  192.308899         8.667    B
# 421567     45    95      56017.47      False  192.308899         8.667    B
# 421568     45    97       6817.48      False  192.308899         8.667    B
# 421569     45    98       1076.80      False  192.308899         8.667    B
#
#           Size   DateTime  Week  Month  Year  SpecialDay
# 0       151315 2010-02-05     5      2  2010          -1
# 1       151315 2010-02-05     5      2  2010          -1
# 2       151315 2010-02-05     5      2  2010          -1
# 3       151315 2010-02-05     5      2  2010          -1
# 4       151315 2010-02-05     5      2  2010          -1
# ...        ...        ...   ...    ...   ...         ...
# 421565  118221 2012-10-26    43     10  2012          -1
# 421566  118221 2012-10-26    43     10  2012          -1
# 421567  118221 2012-10-26    43     10  2012          -1
# 421568  118221 2012-10-26    43     10  2012          -1
# 421569  118221 2012-10-26    43     10  2012          -1
#
# [421570 rows x 13 columns]

# %% [markdown]
# #### 6. Dummies and Label Encoders

# %%
data["IsHoliday"] = data["IsHoliday"].map({False:0,True:1})

# %%
dummies = pd.get_dummies(data["Type"],prefix="Type",dtype=np.int)
data = pd.concat([data,dummies],axis=1)
data
# Out:
#         Store  Dept  Weekly_Sales  IsHoliday         CPI  Unemployment Type  \
# 0           1     1      24924.50          0  211.096358         8.106    A
# 1           1     2      50605.27          0  211.096358         8.106    A
# 2           1     3      13740.12          0  211.096358         8.106    A
# 3           1     4      39954.04          0  211.096358         8.106    A
# 4           1     5      32229.38          0  211.096358         8.106    A
# ...       ...   ...           ...        ...         ...           ...  ...
# 421565     45    93       2487.80          0  192.308899         8.667    B
# 421566     45    94       5203.31          0  192.308899         8.667    B
# 421567     45    95      56017.47          0  192.308899         8.667    B
# 421568     45    97       6817.48          0  192.308899         8.667    B
# 421569     45    98       1076.80          0  192.308899         8.667    B
#
#           Size   DateTime  Week  Month  Year  SpecialDay  Type_A  Type_B  \
# 0       151315 2010-02-05     5      2  2010          -1       1       0
# 1       151315 2010-02-05     5      2  2010          -1       1       0
# 2       151315 2010-02-05     5      2  2010          -1       1       0
# 3       151315 2010-02-05     5      2  2010          -1       1       0
# 4       151315 2010-02-05     5      2  2010          -1       1       0
# ...        ...        ...   ...    ...   ...         ...     ...     ...
# 421565  118221 2012-10-26    43     10  2012          -1       0       1
# 421566  118221 2012-10-26    43     10  2012          -1       0       1
# 421567  118221 2012-10-26    43     10  2012          -1       0       1
# 421568  118221 2012-10-26    43     10  2012          -1       0       1
# 421569  118221 2012-10-26    43     10  2012          -1       0       1
#
#         Type_C
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 421565       0
# 421566       0
# 421567       0
# 421568       0
# 421569       0
#
# [421570 rows x 16 columns]

# %%
data.describe()
# Out:
#                Store           Dept   Weekly_Sales      IsHoliday  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123       0.070358
# std        12.785297      30.492054   22711.183519       0.255750
# min         1.000000       1.000000   -4988.940000       0.000000
# 25%        11.000000      18.000000    2079.650000       0.000000
# 50%        22.000000      37.000000    7612.030000       0.000000
# 75%        33.000000      74.000000   20205.852500       0.000000
# max        45.000000      99.000000  693099.360000       1.000000
#
#                  CPI   Unemployment           Size           Week  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean      171.201947       7.960289  136727.915739      25.826762
# std        39.159276       1.863296   60980.583328      14.151887
# min       126.064000       3.879000   34875.000000       1.000000
# 25%       132.022667       6.891000   93638.000000      14.000000
# 50%       182.318780       7.866000  140167.000000      26.000000
# 75%       212.416993       8.572000  202505.000000      38.000000
# max       227.232807      14.313000  219622.000000      52.000000
#
#                Month           Year     SpecialDay         Type_A  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean        6.449510    2010.968591      -0.838039       0.511132
# std         3.243217       0.796876       0.657140       0.499877
# min         1.000000    2010.000000      -1.000000       0.000000
# 25%         4.000000    2010.000000      -1.000000       0.000000
# 50%         6.000000    2011.000000      -1.000000       1.000000
# 75%         9.000000    2012.000000      -1.000000       1.000000
# max        12.000000    2012.000000       3.000000       1.000000
#
#               Type_B         Type_C
# count  421570.000000  421570.000000
# mean        0.387824       0.101044
# std         0.487255       0.301387
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         1.000000       0.000000
# max         1.000000       1.000000

# %%
data.dtypes
# Out:
# Store                    int64
# Dept                     int64
# Weekly_Sales           float64
# IsHoliday                int64
# CPI                    float64
# Unemployment           float64
# Type                    object
# Size                     int64
# DateTime        datetime64[ns]
# Week                     int64
# Month                    int64
# Year                     int64
# SpecialDay               int64
# Type_A                   int64
# Type_B                   int64
# Type_C                   int64
# dtype: object

# %%
data.to_csv("data/walmart-data.csv",index=False)
data.drop("Type",axis=1,inplace=True)

# %% [markdown]
# #### 7. Features Scaling

# %%
from sklearn.preprocessing import StandardScaler

columns_to_scale = ["CPI","Unemployment","Size","Year"]

scaler = StandardScaler()
scaled = scaler.fit_transform(data[columns_to_scale])
data.drop(columns_to_scale,axis=1,inplace=True)
scaled_df = pd.DataFrame(data=scaled,columns=columns_to_scale)
data = pd.concat([data,scaled_df],axis=1)
data
# Out:
#         Store  Dept  Weekly_Sales  IsHoliday   DateTime  Week  Month  \
# 0           1     1      24924.50          0 2010-02-05     5      2
# 1           1     2      50605.27          0 2010-02-05     5      2
# 2           1     3      13740.12          0 2010-02-05     5      2
# 3           1     4      39954.04          0 2010-02-05     5      2
# 4           1     5      32229.38          0 2010-02-05     5      2
# ...       ...   ...           ...        ...        ...   ...    ...
# 421565     45    93       2487.80          0 2012-10-26    43     10
# 421566     45    94       5203.31          0 2012-10-26    43     10
# 421567     45    95      56017.47          0 2012-10-26    43     10
# 421568     45    97       6817.48          0 2012-10-26    43     10
# 421569     45    98       1076.80          0 2012-10-26    43     10
#
#         SpecialDay  Type_A  Type_B  Type_C       CPI  Unemployment      Size  \
# 0               -1       1       0       0  1.018774      0.078201  0.239209
# 1               -1       1       0       0  1.018774      0.078201  0.239209
# 2               -1       1       0       0  1.018774      0.078201  0.239209
# 3               -1       1       0       0  1.018774      0.078201  0.239209
# 4               -1       1       0       0  1.018774      0.078201  0.239209
# ...            ...     ...     ...     ...       ...           ...       ...
# 421565          -1       0       1       0  0.539003      0.379281 -0.303489
# 421566          -1       0       1       0  0.539003      0.379281 -0.303489
# 421567          -1       0       1       0  0.539003      0.379281 -0.303489
# 421568          -1       0       1       0  0.539003      0.379281 -0.303489
# 421569          -1       0       1       0  0.539003      0.379281 -0.303489
#
#             Year
# 0      -1.215487
# 1      -1.215487
# 2      -1.215487
# 3      -1.215487
# 4      -1.215487
# ...          ...
# 421565  1.294317
# 421566  1.294317
# 421567  1.294317
# 421568  1.294317
# 421569  1.294317
#
# [421570 rows x 15 columns]

# %%
data.to_csv("data/walmart-preprocessing.csv",index=False)
