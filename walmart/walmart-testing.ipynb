# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# #### Import data

# %%
data = pd.read_csv("data/walmart-preprocessing-test.csv")
data
# Out:
#         Store  Dept  IsHoliday    DateTime  Week  Month  SpecialDay  Type_A  \
# 0           1     1          0  2012-11-02    44     11          -1       1
# 1           1     2          0  2012-11-02    44     11          -1       1
# 2           1     3          0  2012-11-02    44     11          -1       1
# 3           1     4          0  2012-11-02    44     11          -1       1
# 4           1     5          0  2012-11-02    44     11          -1       1
# ...       ...   ...        ...         ...   ...    ...         ...     ...
# 115059     45    93          0  2013-07-26    30      7          -1       0
# 115060     45    94          0  2013-07-26    30      7          -1       0
# 115061     45    95          0  2013-07-26    30      7          -1       0
# 115062     45    97          0  2013-07-26    30      7          -1       0
# 115063     45    98          0  2013-07-26    30      7          -1       0
#
# ...

# %% [markdown]
# #### Define X

# %%
X = data.drop(["DateTime"],axis=1)
X
# Out:
#         Store  Dept  IsHoliday  Week  Month  SpecialDay  Type_A  Type_B  \
# 0           1     1          0    44     11          -1       1       0
# 1           1     2          0    44     11          -1       1       0
# 2           1     3          0    44     11          -1       1       0
# 3           1     4          0    44     11          -1       1       0
# 4           1     5          0    44     11          -1       1       0
# ...       ...   ...        ...   ...    ...         ...     ...     ...
# 115059     45    93          0    30      7          -1       0       1
# 115060     45    94          0    30      7          -1       0       1
# 115061     45    95          0    30      7          -1       0       1
# 115062     45    97          0    30      7          -1       0       1
# 115063     45    98          0    30      7          -1       0       1
#
#         Type_C       CPI  Unemployment      Size      Year
# ...

# %% [markdown]
# #### Load model

# %%
import pickle

loaded_model = pickle.load(open("models/RandomForestModel.pkl", 'rb'))
y = loaded_model.predict(X)

# %%
predicted_list = []
for i,row in enumerate(data.values,0):
    Id = f"{str(row[0])}_{str(row[1])}_{str(row[3])}"
    predicted_list.append([Id,y[i]])
predicted_df = pd.DataFrame(data=predicted_list,columns=["Id","Weekly_Sales"])
predicted_df
# Out:
#                       Id  Weekly_Sales
# 0         1_1_2012-11-02    34646.4744
# 1         1_2_2012-11-02    44309.0260
# 2         1_3_2012-11-02     9401.9616
# 3         1_4_2012-11-02    35591.5298
# 4         1_5_2012-11-02    24493.3228
# ...                  ...           ...
# 115059  45_93_2013-07-26     3115.2686
# 115060  45_94_2013-07-26     3081.7199
# 115061  45_95_2013-07-26    59984.9420
# 115062  45_97_2013-07-26     5946.5168
# 115063  45_98_2013-07-26      166.8960
#
# [115064 rows x 2 columns]

# %%
predicted_df.to_csv("outputs/predicted-test.csv",index=False)
