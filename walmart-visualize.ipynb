# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("data/walmart-data.csv")
data
# Out:
#         Store  Dept  Weekly_Sales  IsHoliday         CPI  Unemployment Type  \
# 0           1     1      24924.50          0  211.096358         8.106    A
# 1           1     2      50605.27          0  211.096358         8.106    A
# 2           1     3      13740.12          0  211.096358         8.106    A
# 3           1     4      39954.04          0  211.096358         8.106    A
# 4           1     5      32229.38          0  211.096358         8.106    A
# ...       ...   ...           ...        ...         ...           ...  ...
# 421565     45    93       2487.80          0  192.308899         8.667    B
# 421566     45    94       5203.31          0  192.308899         8.667    B
# 421567     45    95      56017.47          0  192.308899         8.667    B
# 421568     45    97       6817.48          0  192.308899         8.667    B
# 421569     45    98       1076.80          0  192.308899         8.667    B
#
# ...

# %%
data["Type"] = data["Type"].map({"A":3,"B":2,"C":1})

# %%
plt.scatter(data["Size"],data["Weekly_Sales"],c=data["Type"]) # Yellow: A, Green: B, Purple: C
plt.xlabel("Size")
plt.ylabel("Weekly Sales")
plt.show()

# %%
stores_group = data.groupby(['Store']).mean()
stores_group.head()
# Out:
#             Dept  Weekly_Sales  IsHoliday         CPI  Unemployment  Type  \
# Store
# 1      44.391742  21710.543621   0.070578  215.995525      7.610918   3.0
# 2      44.483786  26898.070031   0.070522  215.651869      7.623279   3.0
# 3      41.038623   6373.033983   0.070053  219.402843      7.175602   2.0
# 4      44.522975  29161.210415   0.070775  128.680070      5.965849   3.0
# 5      41.285254   5053.415813   0.071119  216.576516      6.296549   2.0
#
#            Size       Week     Month         Year  SpecialDay  Type_A  Type_B  \
# Store
# 1      151315.0  25.840785  6.453241  2010.964077   -0.837759     1.0     0.0
# 2      202307.0  25.801035  6.443544  2010.966107   -0.837664     1.0     0.0
# 3       37392.0  25.841080  6.452523  2010.965471   -0.838645     0.0     1.0
# 4      205863.0  25.794977  6.442368  2010.965148   -0.837519     1.0     0.0
# 5       34875.0  25.815980  6.446383  2010.966774   -0.835871     0.0     1.0
#
#        Type_C
# Store
# ...

# %%
plt.scatter(stores_group["Size"],stores_group["Weekly_Sales"],c=stores_group["Type"]) # Yellow: A, Green: B, Purple: C
plt.xlabel("Size")
plt.ylabel("Weekly Sales")
plt.show()
